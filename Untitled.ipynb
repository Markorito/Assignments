# %%
import pandas as pd

# %%
data = pd.read_csv('wrangled_freight.csv')
data.head()
# Out:
#         date  Year.x  Month.x  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0  2001/1/20    2020        1       10299     ANC        1      12277    ICN
# 1  2001/1/20    2020        1       10299     ANC        1      11874    GDL
# 2  2001/1/20    2020        1       10194     AFW       74      16178    YQX
# 3  2001/1/20    2020        1       10299     ANC        1      10877    CAN
# 4  2001/1/20    2020        1       10299     ANC        1      12277    ICN
#
#    fg_wac  airlineid  ... Year.y  Month.y          State  COVID.19.Deaths  \
# 0     778      19550  ...   2020        1  United States                5
# 1     148      19779  ...   2020        1  United States                5
# 2     961      20110  ...   2020        1  United States                5
# 3     713      20107  ...   2020        1  United States                5
# 4     778      19917  ...   2020        1  United States                5
#
# ...

# %%
data['Date']
